# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoJOsorio/Modelo_regresion/blob/main/Modelo_de_regresion_ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #

# %%
# Datos
import numpy as np
import pandas as pd

# Visualizacion
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from random import random

# ML
from sklearn.linear_model import LinearRegression, Ridge, SGDRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn import metrics
import xgboost as xgb

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Intro: Regresión Simple Linear

# %%
#Crea dataset ficticio
x=np.arange(0,10,0.1)
y=0.2*x + np.random.normal(2, 3, size=(1, len(x))).flatten()*0.1+0.5
df = pd.DataFrame({'x': x})
df['y']=y.T

# %%
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# TODO: Calcula la correlación de Pearson con numpy.corrcoef

# %%
# Calcular la matriz de correlación y extraer el valor 'r'
matriz_correlacion = np.corrcoef(x.flatten(), y.flatten())
r = matriz_correlacion[0, 1]

print(f"Coeficiente de correlación de Pearson (r): {r}")
# Out:
# Coeficiente de correlación de Pearson (r): 0.8499252796728044

# %% [markdown]
# Fórmulas de parametros alfa y beta:

# %%
#TO DO: Cálcula el parametro alfa de la regresión simple
beta = np.sum((x-np.mean(x)) * (y-np.mean(y)))/np.sum((x-np.mean(x))**2)
alfa = np.mean(y) - (beta * np.mean(x))
print('Fórmula del modelo: y = '+str(np.round(alfa,2))+' + '+str(np.round(beta,2))+'x')
# Out:
# Fórmula del modelo: y = 0.8 + 0.18x

# %% [markdown]
# #TODO: Haz el predict de la regresion simple a partir de los parametros alfa y beta y los datos x

# %%
# y = alfa + beta * x
y_predict = alfa + (beta * x)

# %%
plt.figure()
plt.scatter(x,y)
plt.plot(x,y_predict,'r')
plt.legend(('Regresion Simple', 'Data Original'), loc='lower right')
plt.show()

# %% [markdown]
# Mismo resultado con funciones sklearn....

# %%
model = LinearRegression()
model.fit(x[:, np.newaxis],y)
y_pred2 = model.predict(x[:, np.newaxis])

# %%
print('Sklearn Intercepto (Alfa):', model.intercept_)
print('Sklearn Coeficiente (Beta):', model.coef_[0])
# Out:
# Sklearn Intercepto (Alfa): 0.7959279272466276
# Sklearn Coeficiente (Beta): 0.18122790702643002

# %%
plt.figure()
plt.scatter(x,y)
plt.plot(x,y_pred2,'r')
plt.legend(('Regresion Simple (SKLearn)', 'Data Original'), loc='lower right')
plt.show()
